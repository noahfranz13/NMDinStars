# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
newOut = pd.read_csv('allData.csv')
oldOut = pd.read_csv('/home/ubuntu/Documents/NMDinStars/mesa_mod/mesa-r12778/star/test_suite/NeutrinoMagneticDipoleMesa/WorthyLeeBC/postProcess_output_first.txt')

oldOut.keys(), newOut.keys()
# Out:
# (Index(['0', 'mass_index', 'y_index', 'z_index', 'mu_index', 'mass', 'y', 'z',
#         'mu', 'flag', 'surface_grav', 'Teff', 'feh', 'L', 'worthey_lee_flag',
#         'M_I', 'M_I_err'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'mass_index', 'y_index', 'z_index', 'mu_index', 'mass',
#         'y', 'z', 'mu', 'flag', 'surface_grav', 'Teff', 'feh', 'L',
#         'worthey_lee_flag', 'M_I', 'M_I_err'],
#        dtype='object'))

# %%
def plotHist(key):
    
    plt.figure(figsize=(8,6))
    plt.hist(newOut[key], label='new', alpha=0.7, bins=)
    plt.hist(oldOut[key], label='old', alpha=0.7)
    plt.xlabel(key)
    plt.legend()
    
for k in ['mass', 'y', 'z', 'mu']:
    plotHist(k)
