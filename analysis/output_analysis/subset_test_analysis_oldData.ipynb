# %%
import os, sys, glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb

sb.set(context='talk', style='whitegrid', palette='Set1')

# %%
outdir = '/home/ubuntu/Documents/NMDinStars/mesa_mod/mesa-r12778/star/test_suite/NeutrinoMagneticDipoleMesa/WorthyLeeBC/'
mesaOutFile = outdir + 'postProcess_output_test_.txt'

mags = pd.read_csv(mesaOutFile, index_col=0)
mags[['mass_index', 'y_index', 'z_index', 'mu_index', 'M_I']]
# Out:
#         mass_index  y_index  z_index  mu_index    M_I
# 0
# 100050          13        3       10         0 -2.584
# 100052          13        3       10         2 -2.584
# 100054          13        3       10         4 -2.584
# 100056          13        3       10         6 -2.584
# 100058          13        3       10         8 -2.584
# 100060          13        3       10        10 -2.584
# 100062          13        3       10        12 -2.584
# 100064          13        3       10        14 -2.584
# 100066          13        3       10        16 -2.584
# 100068          13        3       10        18 -2.584
# 100070          13        3       10        20 -2.584
# 100072          13        3       10        22 -2.584
# 100074          13        3       10        24 -2.584
# 100076          13        3       10        26 -2.584
# 100078          13        3       10        28 -2.584
# 100080          13        3       11         0 -2.442
# 100082          13        3       11         2 -2.442
# 100084          13        3       11         4 -2.442
# 100086          13        3       11         6 -2.442
# 100088          13        3       11         8 -2.442
# 100090          13        3       11        10 -2.442
# 100092          13        3       11        12 -2.442
# 100094          13        3       11        14 -2.442
# 100096          13        3       11        16 -2.442
# 100098          13        3       11        18 -2.442
# 100100          13        3       11        20 -2.442
# 100102          13        3       11        22 -2.442
# 100104          13        3       11        24 -2.442
# 100106          13        3       11        26 -2.442
# 100108          13        3       11        28 -2.442
# 100110          13        3       12         0 -4.616
# 100112          13        3       12         2 -4.616
# 100114          13        3       12         4 -4.616
# 100116          13        3       12         6 -4.616
# 100118          13        3       12         8 -4.616
# 100120          13        3       12        10 -4.616
# 100122          13        3       12        12 -4.616
# 100124          13        3       12        14 -4.616
# 100126          13        3       12        16 -4.616
# 100128          13        3       12        18 -4.616
# 100130          13        3       12        20 -4.616
# 100132          13        3       12        22 -4.616
# 100134          13        3       12        24 -4.616
# 100136          13        3       12        26 -4.616
# 100138          13        3       12        28 -4.616
# 100140          13        3       13         0 -4.595
# 100150          13        3       13        10 -4.595
# 100152          13        3       13        12 -4.595
# 100154          13        3       13        14 -4.595
# 100156          13        3       13        16 -4.595

# %%
fig, ax = plt.subplots()
ax.plot(mags.mu, mags.M_I, 'o')
group = mags.groupby(mags.mu).mean().reset_index()
#ax.plot(group.mu,group.M_I, 'o')
ax.set_xlabel('Mu_12')
ax.set_ylabel('I-Band Magnitude')
# Out:
# Text(0, 0.5, 'I-Band Magnitude')

# %%
fig, ax = plt.subplots()
ax.hist(mags.flag)
# Out:
# (array([18.,  0.,  0.,  0.,  0.,  0., 19.,  0.,  0., 13.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)
